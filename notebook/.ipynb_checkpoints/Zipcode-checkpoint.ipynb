# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
map = folium.Map(location=[40.693943, -73.985880], default_zoom_start=15)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d3778ff6c84c> in <module>
# ----> 1 import pandas as pd
#       2 import folium
#       3 from folium.plugins import MarkerCluster
#       4 map = folium.Map(location=[40.693943, -73.985880], default_zoom_start=15)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
folium.Marker(
    location=[40.693943, -73.985880],
    popup='Welcome to <b>NEW YORK CITY</b>',
    tooltip = "Click for more"
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import os
os.getcwd()
# Out:
# '/Users/baidiwang/data-journalism/coronavirus-notebook'

# %%
testzipcode = pd.read_csv('/Users/baidiwang/data-journalism/coronavirus-notebook/data/testzipcode.csv')
testzipcode
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
testzipcode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Zip Code  177 non-null    int64
#  1   Positive  177 non-null    int64
# dtypes: int64(2)
# memory usage: 2.9 KB

# %%
map.choropleth(geo_data="https://raw.githubusercontent.com/fedhere/PUI2015_EC/master/mam1612_EC/nyc-zip-code-tabulation-areas-polygons.geojson",
             data=testzipcode,
             columns=['Zip Code', 'Positive'],
             key_on='feature.properties.postalCode',
             fill_color='BuPu', fill_opacity=0.7, line_opacity=0.3,
             legend_name='Positive Cases')

# %%
hospitals = pd.read_csv('/Users/baidiwang/data-journalism/coronavirus-notebook/data/hospitals.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-176-78c15ba99c08> in <module>
# ----> 1 hospitals = pd.read_csv('/Users/baidiwang/data-journalism/coronavirus-notebook/data/hospitals.csv')
#
# ...

# %%
merged = pd.merge(testzipcode, hospitals, on="Zip Code")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-179-6362a79f9a14> in <module>
# ----> 1 merged = pd.merge(testzipcode, hospitals, on="Zip Code")
#
# NameError: name 'hospitals' is not defined

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Zip Code       63 non-null     int64
#  1   Positive       63 non-null     int64
#  2   Hospital Name  63 non-null     object
#  3   Address        63 non-null     object
#  4   City/Town      63 non-null     object
#  5   County         63 non-null     object
#  6   Latitude       63 non-null     float64
#  7   Longitude      63 non-null     float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.4+ KB

# %%
merged.head()
# Out:
#    Zip Code  Positive                                      Hospital Name  \
# 0     10003       253                             Cabrini Medical Center
# 1     10003       253  Hospital for Joint Diseases Orthopaedic Institute
# 2     10003       253                     New York Eye and Ear Infirmary
# 3     10011       329                            Saint Vincents Hospital
# 4     10016       389                           Bellevue Hospital Center
#
#                 Address  City/Town    County   Latitude  Longitude
# 0  227 East 19th Street  Manhattan  New York  40.735899 -73.983551
# 1  301 East 17th Street  Manhattan  New York  40.734411 -73.983549
# 2  310 East 14th Street  Manhattan  New York  40.731985 -73.984483
# 3  170 West 12th Street  Manhattan  New York  40.736757 -73.999416
# 4      462 First Avenue  Manhattan  New York  40.739540 -73.976333

# %%
marker_cluster = MarkerCluster().add_to(map)

# %%
for i in range(merged.shape[0]):
    location = [merged['LAT'][i],merged['LNG'][i]]
    tooltip = "Zip Code:{}<br> City/Town: {}<br> Click for more".format(merged["ZIP"][i],merged['City/Town'][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/coronavirus-notebook-T4XkMR9U/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LAT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-8ce2bcf6bf6f> in <module>
# ...

# %%
import pandas as pd

# %%
hospitals_read = pd.read_csv('../data/NYCHospitals.csv')
hospitals_read
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 66                               St, Vincent's Campus
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                               Address      City/Town  \
# 0                                1650 Grand Concourse          Bronx
# 1                                   1000 Waters Place          Bronx
# 2                                   1500 Waters Place          Bronx
# ...

# %%
testzipcode_read = pd.read_csv('../data/testzipcode.csv')
testzipcode_read
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
df = pd.DataFrame(hospitals_read)
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 66                               St, Vincent's Campus
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                               Address      City/Town  \
# 0                                1650 Grand Concourse          Bronx
# 1                                   1000 Waters Place          Bronx
# 2                                   1500 Waters Place          Bronx
# ...

# %%
df=df.rename(columns={"Zip Code": 'zipcode'})

# %%
df_zipcode = pd.DataFrame(testzipcode_read)
df_zipcode
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
df=df.dropna()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# ...

# %%
df = df.dropna(axis=0, subset=['zipcode'])
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# ...

# %%
df.columns = df.columns.str.strip()
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# ...

# %%
df.rename(columns={"Zip Code": 'zipcode'})
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# ...

# %%
df = df[df.zipcode != '']
# Out:
# /Users/baidiwang/.local/share/virtualenvs/coronavirus-hospitals-zipcode-SSYinFCk/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df['zipcode']=df['zipcode'].astype(int)

# %%
df.to_csv('../output/hospitals.csv', index=False)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Hospital Name, Address, City/Town, zipcode, County]
# Index: []

# %%
df.isnull().sum()
# Out:
# Hospital Name    0
# Address          0
# City/Town        0
# zipcode          0
# County           0
# dtype: int64

# %%
df_zipcode.isnull().sum()
# Out:
# Zip Code    0
# Positive    0
# dtype: int64

# %%
df_zipcode.columns = df_zipcode.columns.str.strip()

# %%
df_zipcode
# Out:
#      zipcode  Positive
# 0      10001       191
# 1      10002       456
# 2      10003       253
# 3      10004        21
# 4      10005        36
# ..       ...       ...
# 172    11691       941
# 173    11692       246
# 174    11693       167
# 175    11694       302
# 176    11697        52
#
# [177 rows x 2 columns]

# %%
df_zipcode=df_zipcode.rename(columns={"Zip Code": 'zipcode'})
df_zipcode
# Out:
#      zipcode  Positive
# 0      10001       191
# 1      10002       456
# 2      10003       253
# 3      10004        21
# 4      10005        36
# ..       ...       ...
# 172    11691       941
# 173    11692       246
# 174    11693       167
# 175    11694       302
# 176    11697        52
#
# [177 rows x 2 columns]

# %%
result = [df, df_zipcode]
merge= pd.concat(result, on='zipcode')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-d6f8f6c83af9> in <module>
#       1 result = [df, df_zipcode]
# ----> 2 merge= pd.concat(result, on='zipcode')
#
# TypeError: concat() got an unexpected keyword argument 'on'

# %%
df_merge=pd.merge(df, df_zipcode, on='zipcode')

# %%
df_merge
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 58                             Queens Hospital Center
# 59  Saint Vincents Catholic Medical Centers of New...
# 60                     South Beach Psychiatric Center
# 61          Staten Island University Hospital_Concord
# 62  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx    10457
# 1                           1000 Waters Place          Bronx    10461
# 2                           1500 Waters Place          Bronx    10461
# ...

# %%
df.to_csv('../output/finaldata.csv', index=False)
