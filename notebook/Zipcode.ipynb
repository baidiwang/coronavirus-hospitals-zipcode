# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
map = folium.Map(location=[40.693943, -73.985880], default_zoom_start=15)

# %%
import os
os.getcwd()
# Out:
# '/Users/baidiwang/data-journalism/coronavirus-hospitals-zipcode/notebook'

# %%
import pandas as pd

# %%
hospitals_read = pd.read_csv('../data/NYCHospitals_LA.csv')
hospitals_read
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 66                               St, Vincent's Campus
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                               Address      City/Town  \
# 0                                1650 Grand Concourse          Bronx
# 1                                   1000 Waters Place          Bronx
# 2                                   1500 Waters Place          Bronx
# 3                               1740 Eastchester Road          Bronx
# 4           Pelham Parkway South and Eastchester Road          Bronx
# ..                                                ...            ...
# 63                              327 Beach 19th Street   Far Rockaway
# 64                                 777 Seaview Avenue  Staten Island
# 65                                 1050 Targee Street  Staten Island
# 66  see St. Vincent's Catholic Medical Center_ Sta...  Staten Island
# 67                                    355 Bard Avenue  Staten Island
#
#     Zip Code    County   Latitude  Longitude
# 0    10457.0     Bronx  40.843533 -73.911466
# 1    10461.0     Bronx  40.847524 -73.843921
# 2    10461.0     Bronx  40.848782 -73.839363
# 3    10461.0     Bronx  40.847800 -73.844258
# 4    10461.0     Bronx  40.857137 -73.843792
# ..       ...       ...        ...        ...
# 63   11691.0    Queens  40.598028 -73.753132
# 64   10305.0  Richmond  40.583205 -74.082409
# 65   10304.0  Richmond  40.602884 -74.091526
# 66       NaN  Richmond  40.586958 -74.098050
# 67   10310.0  Richmond  40.635546 -74.106478
#
# [68 rows x 7 columns]

# %%
testzipcode_read = pd.read_csv('../data/testzipcode.csv')
testzipcode_read
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
df = pd.DataFrame(hospitals_read)
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 66                               St, Vincent's Campus
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                               Address      City/Town  \
# 0                                1650 Grand Concourse          Bronx
# 1                                   1000 Waters Place          Bronx
# 2                                   1500 Waters Place          Bronx
# 3                               1740 Eastchester Road          Bronx
# 4           Pelham Parkway South and Eastchester Road          Bronx
# ..                                                ...            ...
# 63                              327 Beach 19th Street   Far Rockaway
# 64                                 777 Seaview Avenue  Staten Island
# 65                                 1050 Targee Street  Staten Island
# 66  see St. Vincent's Catholic Medical Center_ Sta...  Staten Island
# 67                                    355 Bard Avenue  Staten Island
#
#     Zip Code    County
# 0    10457.0     Bronx
# 1    10461.0     Bronx
# 2    10461.0     Bronx
# 3    10461.0     Bronx
# 4    10461.0     Bronx
# ..       ...       ...
# 63   11691.0    Queens
# 64   10305.0  Richmond
# 65   10304.0  Richmond
# 66       NaN  Richmond
# 67   10310.0  Richmond
#
# [68 rows x 5 columns]

# %%
df=df.rename(columns={"Zip Code": 'zipcode'})

# %%
df_zipcode = pd.DataFrame(testzipcode_read)
df_zipcode
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
df=df.dropna()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# 3                       1740 Eastchester Road          Bronx  10461.0
# 4   Pelham Parkway South and Eastchester Road          Bronx  10461.0
# ..                                        ...            ...      ...
# 62                         88_25 153rd Street        Jamaica  11432.0
# 63                      327 Beach 19th Street   Far Rockaway  11691.0
# 64                         777 Seaview Avenue  Staten Island  10305.0
# 65                         1050 Targee Street  Staten Island  10304.0
# 67                            355 Bard Avenue  Staten Island  10310.0
#
#       County
# 0      Bronx
# 1      Bronx
# 2      Bronx
# 3      Bronx
# 4      Bronx
# ..       ...
# 62    Queens
# 63    Queens
# 64  Richmond
# 65  Richmond
# 67  Richmond
#
# [64 rows x 5 columns]

# %%
df = df.dropna(axis=0, subset=['zipcode'])
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# 3                       1740 Eastchester Road          Bronx  10461.0
# 4   Pelham Parkway South and Eastchester Road          Bronx  10461.0
# ..                                        ...            ...      ...
# 62                         88_25 153rd Street        Jamaica  11432.0
# 63                      327 Beach 19th Street   Far Rockaway  11691.0
# 64                         777 Seaview Avenue  Staten Island  10305.0
# 65                         1050 Targee Street  Staten Island  10304.0
# 67                            355 Bard Avenue  Staten Island  10310.0
#
#       County
# 0      Bronx
# 1      Bronx
# 2      Bronx
# 3      Bronx
# 4      Bronx
# ..       ...
# 62    Queens
# 63    Queens
# 64  Richmond
# 65  Richmond
# 67  Richmond
#
# [64 rows x 5 columns]

# %%
df.columns = df.columns.str.strip()
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# 3                       1740 Eastchester Road          Bronx  10461.0
# 4   Pelham Parkway South and Eastchester Road          Bronx  10461.0
# ..                                        ...            ...      ...
# 62                         88_25 153rd Street        Jamaica  11432.0
# 63                      327 Beach 19th Street   Far Rockaway  11691.0
# 64                         777 Seaview Avenue  Staten Island  10305.0
# 65                         1050 Targee Street  Staten Island  10304.0
# 67                            355 Bard Avenue  Staten Island  10310.0
#
#       County
# 0      Bronx
# 1      Bronx
# 2      Bronx
# 3      Bronx
# 4      Bronx
# ..       ...
# 62    Queens
# 63    Queens
# 64  Richmond
# 65  Richmond
# 67  Richmond
#
# [64 rows x 5 columns]

# %%
df.rename(columns={"Zip Code": 'zipcode'})
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx  10457.0
# 1                           1000 Waters Place          Bronx  10461.0
# 2                           1500 Waters Place          Bronx  10461.0
# 3                       1740 Eastchester Road          Bronx  10461.0
# 4   Pelham Parkway South and Eastchester Road          Bronx  10461.0
# ..                                        ...            ...      ...
# 62                         88_25 153rd Street        Jamaica  11432.0
# 63                      327 Beach 19th Street   Far Rockaway  11691.0
# 64                         777 Seaview Avenue  Staten Island  10305.0
# 65                         1050 Targee Street  Staten Island  10304.0
# 67                            355 Bard Avenue  Staten Island  10310.0
#
#       County
# 0      Bronx
# 1      Bronx
# 2      Bronx
# 3      Bronx
# 4      Bronx
# ..       ...
# 62    Queens
# 63    Queens
# 64  Richmond
# 65  Richmond
# 67  Richmond
#
# [64 rows x 5 columns]

# %%
df = df[df.zipcode != '']
# Out:
# /Users/baidiwang/.local/share/virtualenvs/coronavirus-hospitals-zipcode-SSYinFCk/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
df['zipcode']=df['zipcode'].astype(int)

# %%
df.to_csv('../output/hospitals.csv', index=False)

# %%
df
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 62  Saint Vincents Catholic Medical Centers of New...
# 63         St. John's Episcopal Hospital_ South Shore
# 64                     South Beach Psychiatric Center
# 65          Staten Island University Hospital_Concord
# 67  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx    10457
# 1                           1000 Waters Place          Bronx    10461
# 2                           1500 Waters Place          Bronx    10461
# 3                       1740 Eastchester Road          Bronx    10461
# 4   Pelham Parkway South and Eastchester Road          Bronx    10461
# ..                                        ...            ...      ...
# 62                         88_25 153rd Street        Jamaica    11432
# 63                      327 Beach 19th Street   Far Rockaway    11691
# 64                         777 Seaview Avenue  Staten Island    10305
# 65                         1050 Targee Street  Staten Island    10304
# 67                            355 Bard Avenue  Staten Island    10310
#
#       County
# 0      Bronx
# 1      Bronx
# 2      Bronx
# 3      Bronx
# 4      Bronx
# ..       ...
# 62    Queens
# 63    Queens
# 64  Richmond
# 65  Richmond
# 67  Richmond
#
# [64 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Hospital Name    0
# Address          0
# City/Town        0
# zipcode          0
# County           0
# dtype: int64

# %%
df_zipcode.isnull().sum()
# Out:
# Zip Code    0
# Positive    0
# dtype: int64

# %%
df_zipcode.columns = df_zipcode.columns.str.strip()

# %%
df_zipcode
# Out:
#      Zip Code  Positive
# 0       10001       191
# 1       10002       456
# 2       10003       253
# 3       10004        21
# 4       10005        36
# ..        ...       ...
# 172     11691       941
# 173     11692       246
# 174     11693       167
# 175     11694       302
# 176     11697        52
#
# [177 rows x 2 columns]

# %%
df_zipcode=df_zipcode.rename(columns={"Zip Code": 'zipcode'})
df_zipcode
# Out:
#      zipcode  Positive
# 0      10001       191
# 1      10002       456
# 2      10003       253
# 3      10004        21
# 4      10005        36
# ..       ...       ...
# 172    11691       941
# 173    11692       246
# 174    11693       167
# 175    11694       302
# 176    11697        52
#
# [177 rows x 2 columns]

# %%
df_merge=pd.merge(df, df_zipcode, on='zipcode')

# %%
df_merge
# Out:
#                                         Hospital Name  \
# 0                       Bronx_Lebanon Hospital Center
# 1                 Bronx Children's Psychiatric Center
# 2                            Bronx Psychiatric Center
# 3                                    Calvary Hospital
# 4                               Jacobi Medical Center
# ..                                                ...
# 58                             Queens Hospital Center
# 59  Saint Vincents Catholic Medical Centers of New...
# 60                     South Beach Psychiatric Center
# 61          Staten Island University Hospital_Concord
# 62  St, Vincent's Catholic Medical Center_Staten I...
#
#                                       Address      City/Town  zipcode  \
# 0                        1650 Grand Concourse          Bronx    10457
# 1                           1000 Waters Place          Bronx    10461
# 2                           1500 Waters Place          Bronx    10461
# 3                       1740 Eastchester Road          Bronx    10461
# 4   Pelham Parkway South and Eastchester Road          Bronx    10461
# ..                                        ...            ...      ...
# 58                         82_68 164th Street        Jamaica    11432
# 59                         88_25 153rd Street        Jamaica    11432
# 60                         777 Seaview Avenue  Staten Island    10305
# 61                         1050 Targee Street  Staten Island    10304
# 62                            355 Bard Avenue  Staten Island    10310
#
#       County  Positive
# 0      Bronx       820
# 1      Bronx       837
# 2      Bronx       837
# 3      Bronx       837
# 4      Bronx       837
# ..       ...       ...
# 58    Queens       710
# 59    Queens       710
# 60  Richmond       540
# 61  Richmond       634
# 62  Richmond       294
#
# [63 rows x 6 columns]

# %%
df.to_csv('../output/finaldata.csv', index=False)
